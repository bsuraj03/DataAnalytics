# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("Sample - Superstore.csv", encoding="latin1")

# First look
print("Shape:", df.shape)
df.head()
# Out:
# Shape: (9994, 21)
#    Row ID        Order ID  Order Date  ... Quantity Discount    Profit
# 0       1  CA-2016-152156   11/8/2016  ...        2     0.00   41.9136
# 1       2  CA-2016-152156   11/8/2016  ...        3     0.00  219.5820
# 2       3  CA-2016-138688   6/12/2016  ...        2     0.00    6.8714
# 3       4  US-2015-108966  10/11/2015  ...        5     0.45 -383.0310
# 4       5  US-2015-108966  10/11/2015  ...        2     0.20    2.5164
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#             Row ID   Postal Code  ...     Discount       Profit
# count  9994.000000   9994.000000  ...  9994.000000  9994.000000
# mean   4997.500000  55190.379428  ...     0.156203    28.656896
# std    2885.163629  32063.693350  ...     0.206452   234.260108
# min       1.000000   1040.000000  ...     0.000000 -6599.978000
# 25%    2499.250000  23223.000000  ...     0.000000     1.728750
# 50%    4997.500000  56430.500000  ...     0.200000     8.666500
# 75%    7495.750000  90008.000000  ...     0.200000    29.364000
# max    9994.000000  99301.000000  ...     0.800000  8399.976000
#
# [8 rows x 6 columns]

# %%
df[df["Profit"]==df["Profit"].min()]
# Out:
#       Row ID        Order ID  Order Date  ... Quantity Discount    Profit
# 7772    7773  CA-2016-108196  11/25/2016  ...        5      0.7 -6599.978
#
# [1 rows x 21 columns]

# %%
loss_orders = df[df["Profit"]<0]
print("Total loss making orders: ", len(loss_orders))
print("Total loss amount: $", round(loss_orders["Profit"].sum(),2))
print("Average loss per order: $", round(loss_orders["Profit"].mean(),2))
# Out:
# Total loss making orders:  1871
# Total loss amount: $ -156131.29
# Average loss per order: $ -83.45

# %%
loss_by_cate = loss_orders.groupby("Category")["Profit"].sum()
print("===Loss by Category===")
print(loss_by_cate.sort_values())
# Out:
# ===Loss by Category===
# Category
# Furniture         -60936.1090
# Office Supplies   -56615.2585
# Technology        -38579.9182
# Name: Profit, dtype: float64

# %%
# Average discount by category for LOSS making orders only
print("=== Average Discount on Loss Orders by Category ===")
print(loss_orders.groupby("Category")["Discount"].mean().sort_values(ascending=False))
# Out:
# === Average Discount on Loss Orders by Category ===
# Category
# Office Supplies    0.617607
# Furniture          0.367143
# Technology         0.333579
# Name: Discount, dtype: float64

# %%
# Visualize profit by category
plt.figure(figsize=(8, 5))
sns.barplot(data=df, x="Category", y="Profit", estimator=sum)
plt.title("Total Profit by Category")
plt.xlabel("Category")
plt.ylabel("Total Profit ($)")
plt.tight_layout()
plt.show()

# %%
# Does higher discount = lower profit?
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="Discount", y="Profit", alpha=0.3)
plt.title("Discount vs Profit")
plt.xlabel("Discount")
plt.ylabel("Profit ($)")
plt.axhline(y=0, color="red", linestyle="--")
plt.tight_layout()
plt.show()
